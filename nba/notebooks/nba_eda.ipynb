# %%
import duckdb

con = duckdb.connect("../data/fieldview.duckdb", read_only=True)

con.sql("SHOW TABLES")
# Out:
# ┌─────────────────┐
# │      name       │
# │     varchar     │
# ├─────────────────┤
# │ nba_contracts   │
# │ nba_depth_chart │
# │ nba_ratings     │
# │ nba_stats       │
# │ player_match    │
# └─────────────────┘

# %%
con.sql(f"SELECT * FROM nba_contracts limit 10")
# Out:
# ┌─────────────────────────┬─────────────────────────┬────────────┬───────────────────────┬─────────┬─────────┬───────┬──────────────────┬──────────────────────┬───────────────────────────┬──────────────────────────┬───────────┬────────┬────────────────────────────┐
# │          name           │      spotrac_name       │ spotrac_id │       name_norm       │   pos   │  team   │  age  │ length_remaining │ cash_total_remaining │ cash_guaranteed_remaining │ pct_guaranteed_remaining │ player_id │ row_id │         loaded_at          │
# │         varchar         │         varchar         │   int64    │        varchar        │ varchar │ varchar │ int64 │      double      │        int64         │           int64           │          double          │  double   │ int64  │         timestamp          │
# ...

# %%
con.sql(f"SELECT * FROM nba_depth_chart limit 10")
# Out:
# ┌───────────┬─────────┬──────────┬────────────┬──────────────────────────┬────────────┬───────────────────┬──────────────┬────────┬────────────────────────────┐
# │ player_id │  team   │ position │ depth_rank │        sheet_name        │ draft_pick │ status_flags_json │ last_changed │ row_id │         loaded_at          │
# │  double   │ varchar │ varchar  │   int64    │         varchar          │   double   │      varchar      │   varchar    │ int64  │         timestamp          │
# ├───────────┼─────────┼──────────┼────────────┼──────────────────────────┼────────────┼───────────────────┼──────────────┼────────┼────────────────────────────┤
# │ 1630168.0 │ ATL     │ C/PF     │          1 │ Onyeka Okongwu           │       NULL │ []                │ 2026-07-26   │      0 │ 2026-08-03 10:08:30.082664 │
# │ 1630552.0 │ ATL     │ PF/SF    │          1 │ Jalen Johnson            │       NULL │ []                │ 2026-07-26   │      1 │ 2026-08-03 10:08:30.082664 │
# ...

# %%
con.sql(f"SELECT * FROM nba_ratings limit 10")
# Out:
# ┌──────────────────────────┬──────────────────────────┬────────────────────────┬─────────┬───────────────┬────────────┬────────────────┬────────────────────────────────────────────────────┬──────────┬──────────┬───────────┬────────┬────────────────────────────┐
# │           name           │         2k_name          │       name_norm        │  team   │ jersey_number │ positions  │ overall_rating │                    profile_url                     │ attr_3pt │ attr_dnk │ player_id │ row_id │         loaded_at          │
# │         varchar          │         varchar          │        varchar         │ varchar │     int64     │  varchar   │     int64      │                      varchar                       │  int64   │  int64   │  double   │ int64  │         timestamp          │
# ...

# %%
con.sql(f"SELECT * FROM nba_stats limit 10")
# Out:
# ┌───────────┬──────────────────┬─────────┬────────┬────────┬────────┬────────┬──────────────┬───────────────┬──────────┬───────────────┬─────────┬────────┬─────────────────┬────────┬────────────────────────────┐
# │ player_id │       name       │  team   │  ppg   │  rpg   │  apg   │  mpg   │ games_played │ games_started │ position │ jersey_number │ height  │ weight │ rotation_status │ row_id │         loaded_at          │
# │   int64   │     varchar      │ varchar │ double │ double │ double │ double │    int64     │     int32     │ varchar  │    varchar    │ varchar │ double │     varchar     │ int64  │         timestamp          │
# ├───────────┼──────────────────┼─────────┼────────┼────────┼────────┼────────┼──────────────┼───────────────┼──────────┼───────────────┼─────────┼────────┼─────────────────┼────────┼────────────────────────────┤
# ...

# %%
con.sql(f"SELECT * FROM player_match limit 10")
# Out:
# ┌───────────┬─────────┬──────────┬─────────────────┬───────────────────┬────────────┬────────────────┬─────────────────┬──────────────────────────┐
# │ player_id │  team   │ position │ rotation_status │  rotation_source  │ depth_rank │ overall_rating │ contract_salary │ contract_years_remaining │
# │   int64   │ varchar │ varchar  │     varchar     │      varchar      │   double   │     double     │     varchar     │          double          │
# ├───────────┼─────────┼──────────┼─────────────────┼───────────────────┼────────────┼────────────────┼─────────────────┼──────────────────────────┤
# │   1630208 │ CHI     │ C        │ bench           │ mpg_derived       │       NULL │           75.0 │ NULL            │                     NULL │
# │   1630209 │ GSW     │ NULL     │ bench           │ mpg_derived       │       NULL │           NULL │ NULL            │                     NULL │
# ...
