# %%
import nflreadpy as nfl
player_stats = nfl.load_player_stats([2025])
# depth_charts = nfl.load_depth_charts([2025])

# %%
player_stats.head()
# Out:
# shape: (5, 115)
# ┌───────────┬───────────┬───────────┬──────────┬───┬───────────┬───────────┬───────────┬───────────┐
# │ player_id ┆ player_na ┆ player_di ┆ position ┆ … ┆ gwfg_bloc ┆ gwfg_dist ┆ fantasy_p ┆ fantasy_p │
# │ ---       ┆ me        ┆ splay_nam ┆ ---      ┆   ┆ ked       ┆ ance      ┆ oints     ┆ oints_ppr │
# │ str       ┆ ---       ┆ e         ┆ str      ┆   ┆ ---       ┆ ---       ┆ ---       ┆ ---       │
# │           ┆ str       ┆ ---       ┆          ┆   ┆ i32       ┆ i32       ┆ f64       ┆ f64       │
# │           ┆           ┆ str       ┆          ┆   ┆           ┆           ┆           ┆           │
# ╞═══════════╪═══════════╪═══════════╪══════════╪═══╪═══════════╪═══════════╪═══════════╪═══════════╡
# │ 00-002345 ┆ A.Rodgers ┆ Aaron     ┆ QB       ┆ … ┆ 0         ┆ 0         ┆ 25.66     ┆ 25.66     │
# │ 9         ┆           ┆ Rodgers   ┆          ┆   ┆           ┆           ┆           ┆           │
# ...

# %%
print(player_stats.columns)
# Out:
# ['player_id', 'player_name', 'player_display_name', 'position', 'position_group', 'headshot_url', 'season', 'week', 'season_type', 'game_id', 'team', 'opponent_team', 'completions', 'attempts', 'passing_yards', 'passing_tds', 'passing_interceptions', 'sacks_suffered', 'sack_yards_lost', 'sack_fumbles', 'sack_fumbles_lost', 'passing_air_yards', 'passing_yards_after_catch', 'passing_first_downs', 'passing_epa', 'passing_cpoe', 'passing_2pt_conversions', 'pacr', 'carries', 'rushing_yards', 'rushing_tds', 'rushing_fumbles', 'rushing_fumbles_lost', 'rushing_first_downs', 'rushing_epa', 'rushing_2pt_conversions', 'receptions', 'targets', 'receiving_yards', 'receiving_tds', 'receiving_fumbles', 'receiving_fumbles_lost', 'receiving_air_yards', 'receiving_yards_after_catch', 'receiving_first_downs', 'receiving_epa', 'receiving_2pt_conversions', 'racr', 'target_share', 'air_yards_share', 'wopr', 'special_teams_tds', 'def_tackles_solo', 'def_tackles_with_assist', 'def_tackle_assists', 'def_tack
# ...

# %%
import pandas as pd

# This is a community-maintained crosswalk, updated regularly
CROSSWALK_URL = "https://github.com/dynastyprocess/data/raw/master/files/db_playerids.csv"

df = pd.read_csv(CROSSWALK_URL)
# Key columns: gsis_id, name, position, team, sleeper_id, espn_id, pff_id
print(df[['gsis_id', 'name', 'position', 'team']].head(20))
# Out:
#       gsis_id                name position team
# 0   MEN516487    Fernando Mendoza       QB  LVR
# 1   SIM639376          Ty Simpson       QB  LAR
# 2         NaN  Trinidad Chambliss       XX   FA
# 3   NUS440041   Garrett Nussmeier       QB  KCC
# 4   BEC122142         Carson Beck       QB  ARI
# 5   KLU066027        Cade Klubnik       QB  NYJ
# 6   ALL015451          Drew Allar       QB  PIT
# 7   DAN558971       Jalon Daniels       QB  TBB
# 8   ALT577722        Luke Altmyer       QB  DET
# 9   PAV369898         Diego Pavia       QB  BAL
# 10  LOV121782      Jeremiyah Love       RB  ARI
# 11  PRI206342      Jadarian Price       RB  SEA
# 12  JOH224817      Emmett Johnson       RB  KCC
# 13  MCG547540        Seth McGowan       RB  IND
# 14  SIN454221  Nicholas Singleton       RB  TEN
# 15  COL293648       Jonah Coleman       RB  DEN
# 16  ALL532376       Kaytron Allen       RB  WAS
# 17        NaN        Le'Veon Moss       RB  MIA
# 18  OTT017302           Jaydn Ott       RB  KCC
# ...
